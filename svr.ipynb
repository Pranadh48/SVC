# %%
# Importing libraries
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Create dataset
x,y = make_regression(
n_samples = 100, # Number of samples
n_features = 1, # Number of features
noise = 10, # Standard deviation of the gaussian noise applied to the output
random_state = 42

)


# Split dataset
x_train, X_test, y_train, y_test = train_test_split(
x,y,
test_size= 0.2,
random_state=42
)

# Create SVR model
svm_regressor = SVR(
kernel= 'rbf',
C=5,
gamma='scale',
epsilon=0.1
)

# Train model
svm_regressor.fit(x_train,y_train)\

# Predict
y_pred = svm_regressor.predict(X_test)
# Evaluate model
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R2 Score:", svm_regressor.score(X_test, y_test))
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
# Out:
# Mean Squared Error: 253.78363605878144
# R2 Score: 0.8475751565727557
# Mean Absolute Error: 11.187353930855728
